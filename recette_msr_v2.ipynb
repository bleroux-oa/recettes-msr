# %%
import pandas as pd
import json
from google.cloud import storage
from google.cloud import bigquery
client = bigquery.Client()

# %% [markdown]
# # Load data

# %% [markdown]
# ## Excel extracts

# %%
pcp_sample_cas_ms = pd.read_excel("Data_msr_v2/samples-RMPCP-CAS.xlsx")
pcp_sample_cosmetochem_ms = pd.read_excel("Data_msr_v2/samples-RMPCP-COSMETOCHEM.xlsx")
pcp_sample_echa_ms = pd.read_excel("Data_msr_v2/samples-RMPCP-ECHA.xlsx")
pcp_sample_lims_ms = pd.read_excel("Data_msr_v2/samples-RMPCP-LIMS-29JUL.xlsx")
pcp_test_lims_ms = pd.read_excel("Data_msr_v2/Tests-RMPCP-LIMS-30JUL.xlsx")

# %%
pcp_sample_cas_ms["id"] = pcp_sample_cas_ms["id"].astype(str)
pcp_sample_cas_ms["external_id"] = pcp_sample_cas_ms["external_id"].astype(str)
pcp_sample_echa_ms["id"] = pcp_sample_echa_ms["id"].astype(str)
pcp_sample_echa_ms["external_id"] = pcp_sample_echa_ms["external_id"].astype(str)
pcp_sample_lims_ms["id"] = pcp_sample_lims_ms["id"].astype(str)
pcp_sample_lims_ms["external_id"] = pcp_sample_lims_ms["external_id"].astype(str)
pcp_sample_cosmetochem_ms["id"] = pcp_sample_cosmetochem_ms["id"].astype(str)
pcp_sample_cosmetochem_ms["external_id"] = pcp_sample_cosmetochem_ms["external_id"].astype(str)
pcp_test_lims_ms["id"] = pcp_test_lims_ms["id"].astype(str)
pcp_test_lims_ms["external_id"] = pcp_test_lims_ms["external_id"].astype(str)

# %% [markdown]
# ## SQL

# %%
with open(f"SQL/msr_v2/get_sample_cas.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_cas_dwh = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_cas_sc_null_allowed.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_cas_dwh_sc_null_allowed = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_cas_sc_null_allowed_aa_cas_allowed.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_cas_dwh_sc_null_allowed_aa_cas_allowed = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_echa.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_echa_dwh = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_aa.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_lims_dwh = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_cosmetochem.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_cosmetochem_dwh = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_aa_no_cas.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_lims_dwh_no_cas = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_sample_aa_no_cas_sc_null_allowed.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_sample_lims_dwh_no_cas_sc_null_allowed = query_job.to_dataframe().drop_duplicates()

# %%
with open(f"SQL/msr_v2/get_test_aa.sql", "r") as sql_file:
    sql_template = sql_file.read()

query_job = client.query(sql_template)
pcp_test_lims_dwh = query_job.to_dataframe().drop_duplicates()

# %% [markdown]
# ## GA function

# %%
def gap_analysis_dataframes(df1: pd.DataFrame, df2: pd.DataFrame):
    """
    Performs a comprehensive gap analysis between two pandas DataFrames.

    This function provides useful information to assess the data gaps, including:
    - Number of lines in both DataFrames.
    - Percentage of NaN (missing) values by attribute for each DataFrame.
    - For attributes with 0% NaN values in both DataFrames, it compares their unique entries,
      reporting:
      - The count of common unique entries.
      - The count of unique entries present only in DataFrame 1 (ms).
      - The count of unique entries present only in DataFrame 2 (dwh).
    
    All values are converted to string type before comparison to prevent type mismatch issues.

    Args:
        df1 (pd.DataFrame): The first pandas DataFrame (e.g., ms).
        df2 (pd.DataFrame): The second pandas DataFrame (e.g., dwh).
    """

    print("--- Starting Gap Analysis between DataFrames ---")
    print(f"\nDataFrame 1 (ms) has {len(df1)} lines.")
    print(f"DataFrame 2 (dwh) has {len(df2)} lines.")

    common_attributes = [
        'id', 'sample_type', 'external_id', 'sample_code', 'fabrication_code',
        'batch_code_number', 'batch_code_supplier', 'sample_ec_code',
        'sample_smiles_code', 'created_at', 'updated_at'
    ]

    # --- NaN Value Analysis ---
    print("\n--- NaN Value Analysis by Attribute ---")
    nan_info = {} # Store NaN percentages for later use in value comparison
    for attr in common_attributes:
        nan_percent_df1 = (df1[attr].isnull().sum() / len(df1)) * 100 if len(df1) > 0 else 0
        nan_percent_df2 = (df2[attr].isnull().sum() / len(df2)) * 100 if len(df2) > 0 else 0
        nan_info[attr] = {'df1': nan_percent_df1, 'df2': nan_percent_df2} # Store percentages

        print(f"\nAttribute: '{attr}'")
        print(f"  - DataFrame 1 (ms): {nan_percent_df1:.2f}% NaN values")
        print(f"  - DataFrame 2 (dwh): {nan_percent_df2:.2f}% NaN values")

        if abs(nan_percent_df1 - nan_percent_df2) > 0.01:
            print(f"  * Note: There is a significant difference in NaN percentages for '{attr}'.")

    # --- Value Comparison for Complete Attributes ---
    print("\n--- Value Comparison for Attributes with 0% NaN ---")
    attributes_compared_for_values = False
    for attr in common_attributes:
        # Only compare values if the attribute has 0% NaN in *both* DataFrames
        if nan_info[attr]['df1'] == 0 and nan_info[attr]['df2'] == 0:
            attributes_compared_for_values = True
            print(f"\nAttribute: '{attr}' (0% NaN in both DataFrames)")

            # Convert column values to string type before converting to sets for consistent comparison
            set1 = set(df1[attr].astype(str).tolist())
            set2 = set(df2[attr].astype(str).tolist())

            common_unique_values = set1.intersection(set2)
            unique_only_in_df1 = set1.difference(set2)
            unique_only_in_df2 = set2.difference(set1)

            print(f"  - Number of common unique entries: {len(common_unique_values)}")
            print(f"  - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): {len(unique_only_in_df1)}")
            print(f"  - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): {len(unique_only_in_df2)}")

            # Optionally, you could print the actual differing values for small sets:
            # if len(unique_only_in_df1) > 0 and len(unique_only_in_df1) < 6:
            #     print(f"    Values unique to DF1: {list(unique_only_in_df1)}")
            # if len(unique_only_in_df2) > 0 and len(unique_only_in_df2) < 6:
            #     print(f"    Values unique to DF2: {list(unique_only_in_df2)}")
        
    if not attributes_compared_for_values:
        print("  No attributes were found with 0% NaN values in both DataFrames to compare individual entries.")

    print("\n--- Gap Analysis Complete ---")

# %% [markdown]
# # SAMPLE PCP

# %% [markdown]
# ## Source CAS

# %%
pcp_sample_cas_ms.sample(n=2)
# Out:
#           id sample_type external_id sample_code  fabrication_code  \
# 17025  34494         CAS     6369591   6369-59-1               NaN
# 10175  41344         CAS    92704079  92704-07-9               NaN
#
#        batch_code_number  batch_code_supplier  sample_ec_code  \
# 17025                NaN                  NaN             NaN
# 10175                NaN                  NaN             NaN
#
#        sample_smiles_code                created_at                updated_at
# 17025                 NaN  2025-04-28T16:33:03.656Z  2025-04-28T16:33:03.656Z
# 10175                 NaN  2025-06-13T16:48:35.716Z  2025-06-13T16:48:35.716Z

# %%
pcp_sample_cas_dwh.sample(n=2)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 2876  48085         CAS     3913711   3913-71-1             None
# 1308  47990         CAS    10043660  10043-66-0             None
#
#      batch_code_number batch_code_supplier sample_ec_code sample_smiles_code  \
# 2876              None                None           None               None
# 1308              None                None           None               None
#
#                            created_at                       updated_at
# 2876 2025-06-20 21:19:18.446666+00:00 2025-06-20 21:19:18.446666+00:00
# 1308 2025-06-20 20:48:22.850000+00:00 2025-06-20 20:48:22.850000+00:00

# %%
gap_analysis_dataframes(pcp_sample_cas_ms, pcp_sample_cas_dwh)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 17391 lines.
# DataFrame 2 (dwh) has 12558 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 12555
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 4836
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 12555
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 4836
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 12555
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 4836
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 12558
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 12558
#
# --- Gap Analysis Complete ---

# %%
# Entries in MS not in DWH 
pcp_sample_cas_ms[~(pcp_sample_cas_ms["external_id"].isin(pcp_sample_cas_dwh["external_id"]))].sample(n=5)
# Out:
#           id sample_type external_id  sample_code  fabrication_code  \
# 9508   42011         CAS    92875097   92875-09-7               NaN
# 10231  41288         CAS    90082829   90082-82-9               NaN
# 12985  38534         CAS   101794745  101794-74-5               NaN
# 16344  35175         CAS   101794905  101794-90-5               NaN
# 11191  40328         CAS   229327939  229327-93-9               NaN
#
#        batch_code_number  batch_code_supplier  sample_ec_code  \
# 9508                 NaN                  NaN             NaN
# 10231                NaN                  NaN             NaN
# 12985                NaN                  NaN             NaN
# 16344                NaN                  NaN             NaN
# 11191                NaN                  NaN             NaN
#
#        sample_smiles_code                created_at                updated_at
# 9508                  NaN  2025-06-13T20:08:24.026Z  2025-06-13T20:08:24.026Z
# 10231                 NaN  2025-06-13T09:48:27.930Z  2025-06-13T09:48:27.930Z
# 12985                 NaN  2025-06-11T16:55:42.003Z  2025-06-11T16:55:42.003Z
# 16344                 NaN  2025-04-30T15:35:24.623Z  2025-04-30T15:35:24.623Z
# 11191                 NaN  2025-06-13T01:42:13.890Z  2025-06-13T01:42:13.890Z

# %% [markdown]
# ## Source CAS (source_code null inclus)

# %%
gap_analysis_dataframes(pcp_sample_cas_ms, pcp_sample_cas_dwh_sc_null_allowed)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 17391 lines.
# DataFrame 2 (dwh) has 17396 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 17396
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 17396
#
# --- Gap Analysis Complete ---

# %%
# Entries in MS not in DWH 
try:
    pcp_sample_cas_ms[~(pcp_sample_cas_ms["external_id"].isin(pcp_sample_cas_dwh_sc_null_allowed["external_id"]))].sample(n=5)
except:
    print("MS contenu dans DWH")
# Out:
# MS contenu dans DWH

# %%
# Entries in dwh not in ms
pcp_sample_cas_dwh_sc_null_allowed[~(pcp_sample_cas_dwh_sc_null_allowed["external_id"].isin(pcp_sample_cas_ms["external_id"]))].head(n=11)
# Out:
#          id source_code sample_type external_id   sample_code  \
# 0     51524        None         CAS  1174327617  1174327-61-7
# 9     51523        None         CAS    68958565    68958-56-5
# 4844  51522  SOURCE_CAS         CAS   183158705   183158-70-5
# 4849  51521  SOURCE_CAS         CAS    32539836    32539-83-6
# 4870  51520  SOURCE_CAS         CAS       87785       87-78-5
#
#      fabrication_code batch_code_number batch_code_supplier sample_ec_code  \
# 0                None              None                None           None
# 9                None              None                None           None
# 4844             None              None                None           None
# 4849             None              None                None           None
# 4870             None              None                None           None
#
#      sample_smiles_code                       created_at  \
# 0                  None 2025-07-28 08:12:18.916666+00:00
# 9                  None 2025-07-28 08:04:50.293333+00:00
# 4844               None 2025-07-25 11:19:56.136666+00:00
# 4849               None 2025-07-23 14:22:55.670000+00:00
# 4870               None 2025-07-23 08:24:26.076666+00:00
#
#                            updated_at
# 0    2025-07-28 08:12:18.916666+00:00
# 9    2025-07-28 08:04:50.293333+00:00
# 4844 2025-07-25 11:19:56.136666+00:00
# 4849 2025-07-23 14:22:55.670000+00:00
# 4870 2025-07-23 08:24:26.076666+00:00

# %% [markdown]
# ## Source CAS (source_code null inclus, AA-CAS inclus)

# %%
gap_analysis_dataframes(pcp_sample_cas_ms, pcp_sample_cas_dwh_sc_null_allowed_aa_cas_allowed)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 17391 lines.
# DataFrame 2 (dwh) has 17396 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 17391
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 17396
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 17391
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 17396
#
# --- Gap Analysis Complete ---

# %%
# Entries in MS not in DWH 
pcp_sample_cas_ms[~(pcp_sample_cas_ms["external_id"].isin(pcp_sample_cas_dwh_sc_null_allowed_aa_cas_allowed["external_id"]))].head(n=7)
# Out:
# Empty DataFrame
# Columns: [id, sample_type, external_id, sample_code, fabrication_code, batch_code_number, batch_code_supplier, sample_ec_code, sample_smiles_code, created_at, updated_at]
# Index: []

# %%
pcp_sample_cas_dwh_sc_null_allowed_aa_cas_allowed[~(pcp_sample_cas_dwh_sc_null_allowed_aa_cas_allowed["external_id"].isin(pcp_sample_cas_ms["external_id"]))].head(n=7)
# Out:
#        id sample_type external_id   sample_code fabrication_code  \
# 1   51524         CAS  1174327617  1174327-61-7             None
# 11  51522         CAS   183158705   183158-70-5             None
# 19  51521         CAS    32539836    32539-83-6             None
# 39  51523         CAS    68958565    68958-56-5             None
# 45  51520         CAS       87785       87-78-5             None
#
#    batch_code_number batch_code_supplier sample_ec_code sample_smiles_code  \
# 1               None                None           None               None
# 11              None                None           None               None
# 19              None                None           None               None
# 39              None                None           None               None
# 45              None                None           None               None
#
#                          created_at                       updated_at
# 1  2025-07-28 08:12:18.916666+00:00 2025-07-28 08:12:18.916666+00:00
# 11 2025-07-25 11:19:56.136666+00:00 2025-07-25 11:19:56.136666+00:00
# 19 2025-07-23 14:22:55.670000+00:00 2025-07-23 14:22:55.670000+00:00
# 39 2025-07-28 08:04:50.293333+00:00 2025-07-28 08:04:50.293333+00:00
# 45 2025-07-23 08:24:26.076666+00:00 2025-07-23 08:24:26.076666+00:00

# %% [markdown]
# ## Source ECHA

# %%
pcp_sample_echa_ms.sample(n=2)
# Out:
#          id sample_type                           external_id sample_code  \
# 1154  10940         CAS  cef821f3-df6e-4a31-952c-26f0aa257517     99-96-7
# 4524   7570         CAS  20feded8-d30d-43c3-a5d2-bae5ff14b5bc   7631-90-5
#
#       fabrication_code  batch_code_number  batch_code_supplier sample_ec_code  \
# 1154               NaN                NaN                  NaN      202-804-9
# 4524               NaN                NaN                  NaN      231-548-0
#
#      sample_smiles_code                created_at                updated_at
# 1154  OC(=O)c1ccc(O)cc1  2025-06-20T15:51:52.730Z  2025-06-20T15:51:52.730Z
# 4524   [Na+].OS(=O)[O-]  2025-04-30T18:48:59.913Z  2025-04-30T18:48:59.913Z

# %%
pcp_sample_echa_dwh.sample(n=2)
# Out:
#         id sample_type                           external_id sample_code  \
# 3859  8518         CAS  59a74557-2396-4831-a256-c1a1a563c06f  68921-45-9
# 232   8164         CAS  39da9a90-1dde-4466-976a-a0b03474ebd2   8050-26-8
#
#      fabrication_code batch_code_number batch_code_supplier sample_ec_code  \
# 3859             None              None                None      272-940-1
# 232              None              None                None      232-479-9
#
#                    sample_smiles_code                       created_at  \
# 3859    Variable; substance is a UVCB 2025-06-13 16:46:30.546666+00:00
# 232   Not Available ( UVCB substance) 2025-06-12 10:34:35.416666+00:00
#
#                            updated_at
# 3859 2025-06-13 16:46:30.546666+00:00
# 232  2025-06-12 10:34:35.416666+00:00

# %%
gap_analysis_dataframes(pcp_sample_echa_ms, pcp_sample_echa_dwh)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 5152 lines.
# DataFrame 2 (dwh) has 5153 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 5.69% NaN values
#   - DataFrame 2 (dwh): 5.69% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 20.30% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#   * Note: There is a significant difference in NaN percentages for 'sample_smiles_code'.
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 5152
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 1
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 5152
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 1
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 5152
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 1
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 5152
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5153
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 5152
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 5153
#
# --- Gap Analysis Complete ---

# %%
# Entries in MS not in DWH 
pcp_sample_echa_ms[~(pcp_sample_echa_ms["external_id"].isin(pcp_sample_echa_dwh["external_id"]))].head(65)
# Out:
# Empty DataFrame
# Columns: [id, sample_type, external_id, sample_code, fabrication_code, batch_code_number, batch_code_supplier, sample_ec_code, sample_smiles_code, created_at, updated_at]
# Index: []

# %%
# Entries in DWH not in MS
pcp_sample_echa_dwh[~(pcp_sample_echa_dwh["external_id"].isin(pcp_sample_echa_ms["external_id"]))].head(1)
# Out:
#       id sample_type                           external_id sample_code  \
# 2  12095         CAS  dd612f10-a5b8-4b78-a087-46eb65dabd48  32539-83-6
#
#   fabrication_code batch_code_number batch_code_supplier sample_ec_code  \
# 2             None              None                None      251-090-5
#
#         sample_smiles_code                       created_at  \
# 2  C1(OCCC2)=C2CCCCCCCCCC1 2025-07-23 14:23:14.883333+00:00
#
#                         updated_at
# 2 2025-07-23 14:23:14.883333+00:00

# %% [markdown]
# ## Source LIMS

# %%
pcp_sample_lims_ms.sample(n=2)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 6596  25113     Refcomm      588922   C61572804              NaN
# 4427  27283     Refcomm      642957   C20177649              NaN
#
#         batch_code_number batch_code_supplier  sample_ec_code  \
# 6596  R0077677A 001 L 001                 NaN             NaN
# 4427  R0038146A 000 L 004                 NaN             NaN
#
#       sample_smiles_code                created_at                updated_at
# 6596                 NaN  2025-07-03T16:44:21.443Z  2025-07-03T16:44:21.443Z
# 4427                 NaN  2025-07-04T08:16:49.910Z  2025-07-04T08:16:49.910Z

# %%
pcp_sample_lims_dwh.sample(n=2)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 144   27772     Refcomm      664011    43471634       DGA2020418
# 4557  25159     Refcomm      591519   C24431487             None
#
#      batch_code_number batch_code_supplier sample_ec_code sample_smiles_code  \
# 144        DGA2020418-                None           None               None
# 4557          P0705059                None           None               None
#
#                            created_at                       updated_at
# 144  2025-07-04 08:59:43.133333+00:00 2025-07-04 08:59:43.133333+00:00
# 4557 2025-07-03 16:45:54.153333+00:00 2025-07-03 16:45:54.153333+00:00

# %%
gap_analysis_dataframes(pcp_sample_lims_ms, pcp_sample_lims_dwh)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 9025 lines.
# DataFrame 2 (dwh) has 8106 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 39.53% NaN values
#   - DataFrame 2 (dwh): 35.36% NaN values
#   * Note: There is a significant difference in NaN percentages for 'fabrication_code'.
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 0.06% NaN values
#   - DataFrame 2 (dwh): 0.06% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 42.56% NaN values
#   - DataFrame 2 (dwh): 38.80% NaN values
#   * Note: There is a significant difference in NaN percentages for 'batch_code_supplier'.
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 8095
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 930
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 11
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 8095
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 930
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3512
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 28
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 8106
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 8106
#
# --- Gap Analysis Complete ---
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 8106
#
# --- Gap Analysis Complete ---

# %%
# Entries in DWH not in MS 
pcp_sample_lims_dwh[~(pcp_sample_lims_dwh["id"].isin(pcp_sample_lims_ms["id"]))].sample(n=5)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 304   22741     Refcomm      875027    46577119      B0000205997
# 2039  28700     Refcomm      790773    B1181217       DGA2220226
# 3915  22715     Refcomm      865228   C23704656       DGA2210221
# 5465  31499     Refcomm      801073   C37994190       DGA2220322
# 3219  22745     Refcomm      874630   C22017913       DGA2350113
#
#           batch_code_number batch_code_supplier sample_ec_code  \
# 304      B0000205997-777033              777033           None
# 2039    DGA2220226-1521I036            1521I036           None
# 3915  DGA2210221-0102459845          0102459845           None
# 5465  DGA2220322-H052K9U153          H052K9U153           None
# 3219  DGA2350113-ESD0904215          ESD0904215           None
#
#      sample_smiles_code                       created_at  \
# 304                None 2025-07-03 13:44:29.560000+00:00
# 2039               None 2025-07-04 14:52:36.863333+00:00
# 3915               None 2025-07-03 13:42:24.836666+00:00
# 5465               None 2025-07-07 12:33:40.800000+00:00
# 3219               None 2025-07-03 13:44:42.396666+00:00
#
#                            updated_at
# 304  2025-07-07 12:45:14.856666+00:00
# 2039 2025-07-04 14:52:37.830000+00:00
# 3915 2025-07-04 08:17:58.160000+00:00
# 5465        2025-07-17 12:24:13+00:00
# 3219 2025-07-04 14:53:29.796666+00:00

# %%
pcp_sample_lims_dwh[~(pcp_sample_lims_dwh["id"].isin(pcp_sample_lims_ms["id"]))]["sample_type"].value_counts()
# Out:
# sample_type
# Refcomm    11
# Name: count, dtype: int64

# %%
# Entries in MS not in DWH 
pcp_sample_lims_ms[~(pcp_sample_lims_ms["external_id"].isin(pcp_sample_lims_dwh["external_id"]))].head()
# Out:
#         id sample_type external_id sample_code fabrication_code  \
# 122  31591     Refcomm      817844   C20042883       DGA23D0069
# 127  31586     Refcomm      817846    49086564       DGA2350354
# 128  31585     Refcomm      817847    64102891      B0000192139
# 129  31584     Refcomm      817845    53013361       DGA2290398
# 134  31579     Refcomm      818640   C23419812       DGA23D0067
#
#           batch_code_number batch_code_supplier  sample_ec_code  \
# 122   DGA23D0069-DGK2350178          DGK2350178             NaN
# 127   DGA2350354-2304B17102          2304B17102             NaN
# 128  B0000192139-22F3913100          22F3913100             NaN
# 129      DGA2290398-7020206             7020206             NaN
# 134   DGA23D0067-DGK1810413          DGK1810413             NaN
#
#      sample_smiles_code                created_at                updated_at
# 122                 NaN  2025-07-07T12:43:58.106Z  2025-07-07T12:43:58.106Z
# 127                 NaN  2025-07-07T12:43:40.880Z  2025-07-07T12:43:40.880Z
# 128                 NaN  2025-07-07T12:43:39.050Z  2025-07-07T12:43:39.050Z
# 129                 NaN  2025-07-07T12:43:37.190Z  2025-07-07T12:43:37.190Z
# 134                 NaN  2025-07-07T12:43:25.683Z  2025-07-07T12:43:25.683Z

# %% [markdown]
# ## Source LIMS (sample_type CAS exclus)

# %%
gap_analysis_dataframes(pcp_sample_lims_ms, pcp_sample_lims_dwh_no_cas)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 9025 lines.
# DataFrame 2 (dwh) has 8106 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 39.53% NaN values
#   - DataFrame 2 (dwh): 35.36% NaN values
#   * Note: There is a significant difference in NaN percentages for 'fabrication_code'.
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 0.06% NaN values
#   - DataFrame 2 (dwh): 0.06% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 42.56% NaN values
#   - DataFrame 2 (dwh): 38.80% NaN values
#   * Note: There is a significant difference in NaN percentages for 'batch_code_supplier'.
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 8095
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 930
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 11
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 8095
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 930
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3512
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 28
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 8106
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 8106
#
# --- Gap Analysis Complete ---

# %%
# Entries in DWH not in MS 
pcp_sample_lims_dwh_no_cas[~(pcp_sample_lims_dwh_no_cas["id"].isin(pcp_sample_lims_ms["id"]))].sample(n=2)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 2042  28701     Refcomm      790773    B1181217       DGA2220226
# 1923  23084     Refcomm      853778    72748924      B0000197661
#
#            batch_code_number batch_code_supplier sample_ec_code  \
# 2042     DGA2220226-1521I036            1521I036           None
# 1923  B0000197661-UB24040008          UB24040008           None
#
#      sample_smiles_code                       created_at  \
# 2042               None 2025-07-04 14:52:40.813333+00:00
# 1923               None 2025-07-03 14:08:42.150000+00:00
#
#                            updated_at
# 2042 2025-07-04 14:53:01.720000+00:00
# 1923 2025-07-17 12:22:21.756666+00:00

# %%
# Entries in MS not in DWH 
pcp_sample_lims_ms[~(pcp_sample_lims_ms["external_id"].isin(pcp_sample_lims_dwh_no_cas["external_id"]))].sample(n=2)
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 3423  28287     Refcomm      649911   C22035504              NaN
# 3444  28266     Refcomm      649922    B1299815              NaN
#
#      batch_code_number batch_code_supplier  sample_ec_code  \
# 3423       0M700174212                 NaN             NaN
# 3444            T52811                 NaN             NaN
#
#       sample_smiles_code                created_at                updated_at
# 3423                 NaN  2025-07-04T10:27:52.060Z  2025-07-04T10:27:52.060Z
# 3444                 NaN  2025-07-04T10:27:13.000Z  2025-07-04T10:27:13.000Z

# %% [markdown]
# ### Deep dive into one entry in DWH not in MS (id: 22716, external_id: 790773, sample_code: B1181217)

# %%
pcp_sample_lims_dwh_no_cas[pcp_sample_lims_dwh_no_cas["sample_code"]=="B1181217"]
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 2039  28700     Refcomm      790773    B1181217       DGA2220226
# 2040  28702     Refcomm      790773    B1181217       DGA2220226
# 2041  22716     Refcomm      790773    B1181217       DGA2220226
# 2042  28701     Refcomm      790773    B1181217       DGA2220226
#
#         batch_code_number batch_code_supplier sample_ec_code  \
# 2039  DGA2220226-1521I036            1521I036           None
# 2040  DGA2220226-1521I036            1521I036           None
# 2041  DGA2220226-1521I036            1521I036           None
# 2042  DGA2220226-1521I036            1521I036           None
#
#      sample_smiles_code                       created_at  \
# 2039               None 2025-07-04 14:52:36.863333+00:00
# 2040               None 2025-07-04 14:53:03.693333+00:00
# 2041               None 2025-07-03 13:42:30.086666+00:00
# 2042               None 2025-07-04 14:52:40.813333+00:00
#
#                            updated_at
# 2039 2025-07-04 14:52:37.830000+00:00
# 2040 2025-07-04 14:53:05.523000+00:00
# 2041 2025-07-04 14:52:33.656666+00:00
# 2042 2025-07-04 14:53:01.720000+00:00

# %%
pcp_sample_lims_ms[pcp_sample_lims_ms["sample_code"]=="B1181217"]
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 3010  28702     Refcomm      790773    B1181217       DGA2220226
#
#         batch_code_number batch_code_supplier  sample_ec_code  \
# 3010  DGA2220226-1521I036            1521I036             NaN
#
#       sample_smiles_code                created_at                updated_at
# 3010                 NaN  2025-07-04T14:53:03.693Z  2025-07-04T14:53:05.523Z

# %% [markdown]
# Les 11 entrées dans le DWH pas dans le MS peuvent être expliqués par ça

# %% [markdown]
# ### Deep dive into one entry in MS not in DWH (id: 23851, external_id: 824825, sample_code: 71634281)

# %%
pcp_sample_lims_dwh_no_cas[pcp_sample_lims_dwh_no_cas["sample_code"]=="71634281"]
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 1812  24169     Refcomm      824779    71634281      B0000195906
# 1813  28680     Refcomm      824730    71634281      B0000195906
# 1814  28697     Refcomm      824761    71634281      B0000195906
#
#         batch_code_number batch_code_supplier sample_ec_code  \
# 1812  B0000195906-K-64162             K-64162           None
# 1813  B0000195906-K-64162             K-64162           None
# 1814  B0000195906-K-64162             K-64162           None
#
#      sample_smiles_code                       created_at  \
# 1812               None 2025-07-03 15:49:54.566666+00:00
# 1813               None 2025-07-04 11:09:10.490000+00:00
# 1814               None 2025-07-04 11:09:58.930000+00:00
#
#                            updated_at
# 1812 2025-07-03 15:49:54.566666+00:00
# 1813 2025-07-04 11:09:10.490000+00:00
# 1814 2025-07-04 11:09:58.930000+00:00

# %%
pcp_sample_lims_ms[pcp_sample_lims_ms["sample_code"]=="71634281"]
# Out:
#          id sample_type external_id sample_code fabrication_code  \
# 3013  28697     Refcomm      824761    71634281      B0000195906
# 3030  28680     Refcomm      824730    71634281      B0000195906
# 7540  24169     Refcomm      824779    71634281      B0000195906
# 7858  23851     Refcomm      824825    71634281      B0000195906
#
#         batch_code_number batch_code_supplier  sample_ec_code  \
# 3013  B0000195906-K-64162             K-64162             NaN
# 3030  B0000195906-K-64162             K-64162             NaN
# 7540  B0000195906-K-64162             K-64162             NaN
# 7858  B0000195906-K-64162             K-64162             NaN
#
#       sample_smiles_code                created_at                updated_at
# 3013                 NaN  2025-07-04T11:09:58.930Z  2025-07-04T11:09:58.930Z
# 3030                 NaN  2025-07-04T11:09:10.490Z  2025-07-04T11:09:10.490Z
# 7540                 NaN  2025-07-03T15:49:54.566Z  2025-07-03T15:49:54.566Z
# 7858                 NaN  2025-07-03T15:00:26.550Z  2025-07-03T15:00:26.550Z

# %% [markdown]
# Il y a bien un id 23851 en DWH MSR mais son source_code est null ! Donc la clause source_code = "ANALYSE_AULNAY" le fait disparaître à tort

# %% [markdown]
# ## Source LIMS (sample_type CAS exclus, source_code null inclus)

# %%
gap_analysis_dataframes(pcp_sample_lims_ms, pcp_sample_lims_dwh_no_cas_sc_null_allowed)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 9025 lines.
# DataFrame 2 (dwh) has 9036 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 39.53% NaN values
#   - DataFrame 2 (dwh): 39.49% NaN values
#   * Note: There is a significant difference in NaN percentages for 'fabrication_code'.
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 0.06% NaN values
#   - DataFrame 2 (dwh): 0.06% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 42.56% NaN values
#   - DataFrame 2 (dwh): 42.50% NaN values
#   * Note: There is a significant difference in NaN percentages for 'batch_code_supplier'.
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 9025
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 11
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 9025
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3540
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 9036
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 9025
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 9036
#
# --- Gap Analysis Complete ---

# %% [markdown]
# Leurs id sont consécutifs !

# %%
# Entries in MS not in DWH 
pcp_sample_lims_ms[~(pcp_sample_lims_ms["external_id"].isin(pcp_sample_lims_dwh_no_cas_sc_null_allowed["external_id"]))].head(65)
# Out:
# Empty DataFrame
# Columns: [id, sample_type, external_id, sample_code, fabrication_code, batch_code_number, batch_code_supplier, sample_ec_code, sample_smiles_code, created_at, updated_at]
# Index: []

# %%
# Entries in DWH not in MS 
pcp_sample_lims_dwh_no_cas_sc_null_allowed[~(pcp_sample_lims_dwh_no_cas_sc_null_allowed["id"].isin(pcp_sample_lims_ms["id"]))]\
    [["id","external_id","sample_code"]].head(11)
# Out:
#          id external_id sample_code
# 345   22741      875027    46577119
# 932   23075      849774    51993750
# 1696  26931      801585    63830958
# 2027  23084      853778    72748924
# 2150  28700      790773    B1181217
# 2152  22716      790773    B1181217
# 2153  28701      790773    B1181217
# 3441  22745      874630   C22017913
# 4170  22718      798601   C23703964
# 4195  22715      865228   C23704656
# 5965  31499      801073   C37994190

# %% [markdown]
# ## Source COSMETOCHEM

# %%
gap_analysis_dataframes(pcp_sample_cosmetochem_ms, pcp_sample_cosmetochem_dwh)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 3368 lines.
# DataFrame 2 (dwh) has 3371 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'sample_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'fabrication_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_number'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'batch_code_supplier'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_ec_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'sample_smiles_code'
#   - DataFrame 1 (ms): 100.00% NaN values
#   - DataFrame 2 (dwh): 100.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3368
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 1
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3368
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'sample_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 3368
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 3368
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3371
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 3368
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 3371
#
# --- Gap Analysis Complete ---

# %%
# Entrées en DWH pas en MS (Ras juste de la récence)
pcp_sample_cosmetochem_dwh[~(pcp_sample_cosmetochem_dwh["id"].isin(pcp_sample_cosmetochem_ms["id"]))].head(11)
# Out:
#       id sample_type external_id  sample_code fabrication_code  \
# 4   6927         CAS   183158705  183158-70-5             None
# 8   6926         CAS    32539836   32539-83-6             None
# 21  6925         CAS       87785      87-78-5             None
#
#    batch_code_number batch_code_supplier sample_ec_code sample_smiles_code  \
# 4               None                None           None               None
# 8               None                None           None               None
# 21              None                None           None               None
#
#                          created_at                       updated_at
# 4  2025-07-25 11:22:52.740000+00:00 2025-07-25 11:22:52.740000+00:00
# 8  2025-07-23 14:25:47.430000+00:00 2025-07-23 14:25:47.430000+00:00
# 21 2025-07-23 08:36:26.720000+00:00 2025-07-23 08:36:26.720000+00:00

# %%
pcp_sample_cosmetochem_ms[pcp_sample_cosmetochem_ms["id"]=="6926"]
# Out:
# Empty DataFrame
# Columns: [id, sample_type, external_id, sample_code, fabrication_code, batch_code_number, batch_code_supplier, sample_ec_code, sample_smiles_code, created_at, updated_at]
# Index: []

# %% [markdown]
# # TEST PCP

# %% [markdown]
# ## GA function test

# %%
def gap_analysis_dataframes_test(df1: pd.DataFrame, df2: pd.DataFrame):
    """
    Performs a comprehensive gap analysis between two pandas DataFrames.

    This function provides useful information to assess the data gaps, including:
    - Number of lines in both DataFrames.
    - Percentage of NaN (missing) values by attribute for each DataFrame.
    - For attributes with 0% NaN values in both DataFrames, it compares their unique entries,
      reporting:
      - The count of common unique entries.
      - The count of unique entries present only in DataFrame 1 (ms).
      - The count of unique entries present only in DataFrame 2 (dwh).
    
    All values are converted to string type before comparison to prevent type mismatch issues.

    Args:
        df1 (pd.DataFrame): The first pandas DataFrame (e.g., ms).
        df2 (pd.DataFrame): The second pandas DataFrame (e.g., dwh).
    """

    print("--- Starting Gap Analysis between DataFrames ---")
    print(f"\nDataFrame 1 (ms) has {len(df1)} lines.")
    print(f"DataFrame 2 (dwh) has {len(df2)} lines.")

    common_attributes = ['external_id', 'tested_sample_id',
       'measure_objective_type_code', 'test_sub_type', 'test_name',
       'test_variation', 'test_version', 'test_validation_date', 'created_at',
       'updated_at']

    # --- NaN Value Analysis ---
    print("\n--- NaN Value Analysis by Attribute ---")
    nan_info = {} # Store NaN percentages for later use in value comparison
    for attr in common_attributes:
        nan_percent_df1 = (df1[attr].isnull().sum() / len(df1)) * 100 if len(df1) > 0 else 0
        nan_percent_df2 = (df2[attr].isnull().sum() / len(df2)) * 100 if len(df2) > 0 else 0
        nan_info[attr] = {'df1': nan_percent_df1, 'df2': nan_percent_df2} # Store percentages

        print(f"\nAttribute: '{attr}'")
        print(f"  - DataFrame 1 (ms): {nan_percent_df1:.2f}% NaN values")
        print(f"  - DataFrame 2 (dwh): {nan_percent_df2:.2f}% NaN values")

        if abs(nan_percent_df1 - nan_percent_df2) > 0.01:
            print(f"  * Note: There is a significant difference in NaN percentages for '{attr}'.")

    # --- Value Comparison for Complete Attributes ---
    print("\n--- Value Comparison for Attributes with 0% NaN ---")
    attributes_compared_for_values = False
    for attr in common_attributes:
        # Only compare values if the attribute has 0% NaN in *both* DataFrames
        if nan_info[attr]['df1'] == 0 and nan_info[attr]['df2'] == 0:
            attributes_compared_for_values = True
            print(f"\nAttribute: '{attr}' (0% NaN in both DataFrames)")

            # Convert column values to string type before converting to sets for consistent comparison
            set1 = set(df1[attr].astype(str).tolist())
            set2 = set(df2[attr].astype(str).tolist())

            common_unique_values = set1.intersection(set2)
            unique_only_in_df1 = set1.difference(set2)
            unique_only_in_df2 = set2.difference(set1)

            print(f"  - Number of common unique entries: {len(common_unique_values)}")
            print(f"  - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): {len(unique_only_in_df1)}")
            print(f"  - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): {len(unique_only_in_df2)}")

            # Optionally, you could print the actual differing values for small sets:
            # if len(unique_only_in_df1) > 0 and len(unique_only_in_df1) < 6:
            #     print(f"    Values unique to DF1: {list(unique_only_in_df1)}")
            # if len(unique_only_in_df2) > 0 and len(unique_only_in_df2) < 6:
            #     print(f"    Values unique to DF2: {list(unique_only_in_df2)}")
        
    if not attributes_compared_for_values:
        print("  No attributes were found with 0% NaN values in both DataFrames to compare individual entries.")

    print("\n--- Gap Analysis Complete ---")

# %% [markdown]
# ## Processing

# %%
pcp_test_lims_ms.head(2)
# Out:
#       id  measure_objective_type_id measure_objective_type_code external_id  \
# 0  60110                          2                   WET_POINT     1470782
# 1  60109                          1                  DENSITY_01     1470781
#
#    tested_sample_id  source_id     source_code  method_id  \
# 0             31711          6  ANALYSE_AULNAY       86.0
# 1             31711          6  ANALYSE_AULNAY       79.0
#
#              method_code test_type  ... device_id input_structure_smiles  \
# 0         METHOD_NO_INFO    Mesure  ...       NaN                    NaN
# 1  METHOD_CID_025_00_URL    Mesure  ...       NaN                    NaN
#
#   clean_structure_smiles version  reviewer_role                created_at  \
# 0                    NaN     NaN     AU_RES_DEM  2025-07-23T12:59:41.560Z
# 1                    NaN     NaN     AU_RES_DEM  2025-07-23T12:59:37.690Z
#
#                  updated_at  deleted_at  tested_operating_parameters  \
# 0  2025-07-23T12:59:41.560Z         NaN                          NaN
# 1  2025-07-23T12:59:37.690Z         NaN                          NaN
#
#    individual_measurements
# 0                      NaN
# 1                      NaN
#
# [2 rows x 29 columns]

# %%
pcp_test_lims_dwh.head(2)
# Out:
#       id external_id tested_sample_id measure_objective_type_code  \
# 0  43894     1535948            23197              CHARGE_DENSITY
# 1  49776     1598430            25482              CHARGE_DENSITY
#
#     test_sub_type            test_name    test_variation test_version  \
# 0  MEAS_PHYS_CHEM  MEAS_CHARGE_DENSITY  ANIONIC-CATIONIC            1
# 1  MEAS_PHYS_CHEM  MEAS_CHARGE_DENSITY  ANIONIC-CATIONIC            1
#
#        test_validation_date                       created_at  \
# 0 2023-08-01 14:21:11+00:00 2025-07-03 14:18:51.490000+00:00
# 1 2024-03-27 10:05:32+00:00 2025-07-04 08:38:05.343333+00:00
#
#                         updated_at
# 0 2025-07-03 14:18:51.490000+00:00
# 1 2025-07-04 08:38:05.343333+00:00

# %%
gap_analysis_dataframes_test(pcp_test_lims_ms, pcp_test_lims_dwh)
# Out:
# --- Starting Gap Analysis between DataFrames ---
#
# DataFrame 1 (ms) has 15610 lines.
# DataFrame 2 (dwh) has 15660 lines.
#
# --- NaN Value Analysis by Attribute ---
#
# Attribute: 'external_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'tested_sample_id'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'measure_objective_type_code'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'test_sub_type'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'test_name'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'test_variation'
#   - DataFrame 1 (ms): 31.48% NaN values
#   - DataFrame 2 (dwh): 31.48% NaN values
#
# Attribute: 'test_version'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'test_validation_date'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'created_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# Attribute: 'updated_at'
#   - DataFrame 1 (ms): 0.00% NaN values
#   - DataFrame 2 (dwh): 0.00% NaN values
#
# --- Value Comparison for Attributes with 0% NaN ---
#
# Attribute: 'external_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 15610
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 25
#
# Attribute: 'tested_sample_id' (0% NaN in both DataFrames)
#   - Number of common unique entries: 8095
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 11
#
# Attribute: 'measure_objective_type_code' (0% NaN in both DataFrames)
#   - Number of common unique entries: 34
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'test_sub_type' (0% NaN in both DataFrames)
#   - Number of common unique entries: 2
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'test_name' (0% NaN in both DataFrames)
#   - Number of common unique entries: 27
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'test_version' (0% NaN in both DataFrames)
#   - Number of common unique entries: 4
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 0
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 0
#
# Attribute: 'test_validation_date' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 7874
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 7902
#
# Attribute: 'created_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 15610
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 15660
#
# Attribute: 'updated_at' (0% NaN in both DataFrames)
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 15610
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 15658
#
# --- Gap Analysis Complete ---
#   - Number of common unique entries: 0
#   - Number of unique entries only in DataFrame 1 (pcp_sample_cas_ms): 15610
#   - Number of unique entries only in DataFrame 2 (pcp_sample_cas_dwh): 15658
#
# --- Gap Analysis Complete ---

# %% [markdown]
# Pourquoi le DWH dépasse sur le MS ? Des données inactives mal filtrées ? Quelques samples concentrent plusieurs entrées en écart

# %%
# Inspect 50 entries in DWH not in MS 
pcp_test_lims_dwh[~(pcp_test_lims_dwh["id"].isin(pcp_test_lims_ms["id"]))]
# Out:
#           id external_id tested_sample_id measure_objective_type_code  \
# 48     43263     1704205            22702               TURBIDITY_GEL
# 107    43322     1719506            22715  VISCOSITY_VS_CONCENTRATION
# 108    43323     1732235            22716  VISCOSITY_VS_CONCENTRATION
# 109    43324     1611267            22717               TURBIDITY_GEL
# 111    43326     1611268            22717  VISCOSITY_VS_CONCENTRATION
# 113    43328     1704206            22702  VISCOSITY_VS_CONCENTRATION
# 114    43329     1733426            22718  VISCOSITY_VS_CONCENTRATION
# 146    43361     1738628            22741  VISCOSITY_VS_CONCENTRATION
# 150    43365     1735884            22745       RHEOLOGICAL_PROP_FLOW
# 168    43383     1550441            22759              ZETA_POTENTIAL
# 169    43384     1725258            22759       RHEOLOGICAL_PROP_FLOW
# 170    43385     1733431            22759  VISCOSITY_VS_CONCENTRATION
# 171    43386     1550440            22759                    IONICITY
# 172    43387     1733424            22760  VISCOSITY_VS_CONCENTRATION
# 173    43388     1568157            22759           GLASS_TRANSITION_
# 174    43389     1733423            22760               TURBIDITY_GEL
# 175    43390     1733430            22759               TURBIDITY_GEL
# 252    43467     1719500            22815               TURBIDITY_GEL
# 255    43470     1719499            22815  VISCOSITY_VS_CONCENTRATION
# 290    43505     1714162            22852       RHEOLOGICAL_PROP_FLOW
# 535    43751     1668253            23075                      CC_HLD
# 544    43760     1696719            23084                         HSP
# 4127   47471     1474742            25899                   VISCOSITY
# 4607   48255     1570602            22852  VISCOSITY_VS_CONCENTRATION
# 5474   49122     1557712            26931                         HSP
# 6741   50949     1550058            22852                    IONICITY
# 6750   50958     1550059            22852              ZETA_POTENTIAL
# 7211   51424     1732235            28700  VISCOSITY_VS_CONCENTRATION
# 7212   51425     1732235            28701  VISCOSITY_VS_CONCENTRATION
# 7243   51458     1733426            28711  VISCOSITY_VS_CONCENTRATION
# 7244   51459     1733425            28711               TURBIDITY_GEL
# 13601  58028     1505391            25899                  SOLUBILITY
# 13608  58035     1505393            25899                  SOLUBILITY
# 13630  58057     1505392            25899                  SOLUBILITY
# 13632  58059     1505390            25899                          PH
# 13761  58188     1494803            25899             SURFACE_TENSION
# 13775  58202     1493138            25899           EVAPORATION_SPEED
# 14002  58429     1474618            25899            REFRACTIVE_INDEX
# 14011  58438     1473936            25899                  DENSITY_02
# 15181  59621     1555869            31499              VAPOR_PRESSURE
# 15560  60011     1744256            31673                          PH
# 15561  60012     1744255            31673                  DENSITY_02
# 15583  60034     1744387            31673                   VISCOSITY
# 15584  60035     1744257            31673            REFRACTIVE_INDEX
# 15628  60079     1470782            31711                   WET_POINT
# 15636  60087     1491092            31711                  DENSITY_01
# 15639  60090     1470800            31711              ZETA_POTENTIAL
# 15641  60092     1470784            31711              HYDROPHOBICITY
# 15646  60097     1470781            31711                  DENSITY_01
# 15650  60101     1470804            31711                   WET_POINT
#
#         test_sub_type                   test_name        test_variation  \
# 48     MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 107    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 108    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 109    MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 111    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 113    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 114    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 146    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 150            PROFIL             PROFIL_RHEOLOGY                  FLOW
# 168    MEAS_PHYS_CHEM               MEAS_POT_ZETA                  None
# 169            PROFIL             PROFIL_RHEOLOGY                  FLOW
# 170    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 171    MEAS_PHYS_CHEM         MEAS_CHARGE_DENSITY      ANIONIC-CATIONIC
# 172    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 173            PROFIL              PROFIL_THERMAL   TRANSITION_VITREUSE
# 174    MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 175    MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 252    MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 255    MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 290            PROFIL             PROFIL_RHEOLOGY                  FLOW
# 535    MEAS_PHYS_CHEM                    MEAS_HLD        CC_SURFACTANTS
# 544    MEAS_PHYS_CHEM  MEAS_HANSEN_SIMILARITY_PAR         DOUBLE_SPHERE
# 4127   MEAS_PHYS_CHEM              MEAS_VISCOSITY     VIP_NEWTONIAN_LIQ
# 4607   MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 5474   MEAS_PHYS_CHEM  MEAS_HANSEN_SIMILARITY_PAR         DOUBLE_SPHERE
# 6741   MEAS_PHYS_CHEM         MEAS_CHARGE_DENSITY      ANIONIC-CATIONIC
# 6750   MEAS_PHYS_CHEM               MEAS_POT_ZETA                  None
# 7211   MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 7212   MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 7243   MEAS_PHYS_CHEM              MEAS_VISCOSITY  VISCOSITY_VS_CONCENT
# 7244   MEAS_PHYS_CHEM              MEAS_TURBIDITY                  None
# 13601  MEAS_PHYS_CHEM             MEAS_SOLUBILITY                CLASSE
# 13608  MEAS_PHYS_CHEM             MEAS_SOLUBILITY                CLASSE
# 13630  MEAS_PHYS_CHEM             MEAS_SOLUBILITY                CLASSE
# 13632  MEAS_PHYS_CHEM             MEAS_SOLUBILITY                CLASSE
# 13761  MEAS_PHYS_CHEM        MEAS_SURFACE_TENSION                    TS
# 13775  MEAS_PHYS_CHEM      MEAS_EVAPORATION_SPEED                  None
# 14002  MEAS_PHYS_CHEM       MEAS_REFRACTIVE_INDEX                  None
# 14011  MEAS_PHYS_CHEM                MEAS_DENSITY                LIQUID
# 15181  MEAS_PHYS_CHEM         MEAS_VAPOR_PRESSURE                  None
# 15560  MEAS_PHYS_CHEM                     MEAS_PH           WITHOUT_DIL
# 15561  MEAS_PHYS_CHEM                MEAS_DENSITY                LIQUID
# 15583  MEAS_PHYS_CHEM              MEAS_VISCOSITY     VIP_NEWTONIAN_LIQ
# 15584  MEAS_PHYS_CHEM       MEAS_REFRACTIVE_INDEX                  None
# 15628  MEAS_PHYS_CHEM      MEAS_LIQUID_ABSORPTION                  None
# 15636  MEAS_PHYS_CHEM                MEAS_DENSITY                POWDER
# 15639  MEAS_PHYS_CHEM               MEAS_POT_ZETA                  None
# 15641          PROFIL       PROFIL_HYDROPHOBICITY                  None
# 15646  MEAS_PHYS_CHEM                MEAS_DENSITY                POWDER
# 15650  MEAS_PHYS_CHEM      MEAS_LIQUID_ABSORPTION                  None
#
#       test_version      test_validation_date                       created_at  \
# 48               1 2025-06-23 14:15:32+00:00 2025-07-03 13:39:57.700000+00:00
# 107              4 2025-06-22 14:29:26+00:00 2025-07-03 13:42:24.866666+00:00
# 108              4 2025-06-22 13:47:22+00:00 2025-07-03 13:42:30.140000+00:00
# 109              1 2025-06-22 14:22:16+00:00 2025-07-03 13:42:41.933333+00:00
# 111              3 2025-06-22 14:22:16+00:00 2025-07-03 13:42:57.436666+00:00
# 113              4 2025-06-22 13:21:28+00:00 2025-07-03 13:43:02.273333+00:00
# 114              4 2025-06-22 13:43:18+00:00 2025-07-03 13:43:05.016666+00:00
# 146              4 2025-06-06 13:43:04+00:00 2025-07-03 13:44:29.636666+00:00
# 150              2 2025-05-28 16:34:28+00:00 2025-07-03 13:44:42.423333+00:00
# 168              3 2025-05-21 16:32:57+00:00 2025-07-03 13:45:35.786666+00:00
# 169              2 2025-05-21 16:32:58+00:00 2025-07-03 13:45:50.636666+00:00
# 170              4 2025-05-21 16:32:58+00:00 2025-07-03 13:46:06.926666+00:00
# 171              1 2025-05-21 16:32:57+00:00 2025-07-03 13:46:21.836666+00:00
# 172              4 2025-05-21 16:04:34+00:00 2025-07-03 13:46:35.743333+00:00
# 173              3 2025-05-21 16:32:59+00:00 2025-07-03 13:46:51.800000+00:00
# 174              1 2025-05-21 16:01:58+00:00 2025-07-03 13:47:03.873333+00:00
# 175              1 2025-05-21 16:32:58+00:00 2025-07-03 13:47:20.670000+00:00
# 252              1 2025-04-03 17:32:12+00:00 2025-07-03 13:50:38.180000+00:00
# 255              4 2025-04-03 17:32:12+00:00 2025-07-03 13:51:13.436666+00:00
# 290              2 2025-03-20 16:05:04+00:00 2025-07-03 13:52:36.950000+00:00
# 535              1 2025-02-04 16:17:52+00:00 2025-07-03 14:08:09.810000+00:00
# 544              2 2025-02-04 13:40:20+00:00 2025-07-03 14:08:42.176666+00:00
# 4127             1 2023-01-16 16:13:17+00:00 2025-07-03 17:48:06.803333+00:00
# 4607             3 2024-04-10 12:10:51+00:00 2025-07-04 07:15:04.406666+00:00
# 5474             2 2023-10-06 11:02:08+00:00 2025-07-04 08:04:08.273333+00:00
# 6741             1 2024-04-10 12:10:51+00:00 2025-07-04 10:37:46.156666+00:00
# 6750             3 2024-04-10 12:10:51+00:00 2025-07-04 10:38:27.083333+00:00
# 7211             4 2025-07-04 13:15:12+00:00 2025-07-04 14:52:36.913333+00:00
# 7212             4 2025-07-04 13:40:34+00:00 2025-07-04 14:52:40.860000+00:00
# 7243             4 2025-07-04 16:13:59+00:00 2025-07-04 15:14:24.013333+00:00
# 7244             1 2025-07-04 16:13:59+00:00 2025-07-04 15:14:25.900000+00:00
# 13601            2 2023-04-25 17:09:31+00:00 2025-07-07 08:56:59.066666+00:00
# 13608            2 2023-04-25 17:09:31+00:00 2025-07-07 08:57:40.293333+00:00
# 13630            2 2023-04-25 17:09:31+00:00 2025-07-07 08:58:38.286666+00:00
# 13632            2 2023-04-25 17:09:30+00:00 2025-07-07 08:58:54.440000+00:00
# 13761            1 2023-03-21 09:30:24+00:00 2025-07-07 09:11:23.110000+00:00
# 13775            1 2023-03-15 15:46:13+00:00 2025-07-07 09:12:06.043333+00:00
# 14002            1 2023-01-16 16:13:17+00:00 2025-07-07 09:23:54.136666+00:00
# 14011            2 2023-01-16 16:13:17+00:00 2025-07-07 09:24:13.846666+00:00
# 15181            1 2024-03-02 08:13:15+00:00 2025-07-07 12:33:40.846666+00:00
# 15560            2 2025-07-16 09:24:37+00:00 2025-07-17 12:21:26.693333+00:00
# 15561            3 2025-07-16 09:24:37+00:00 2025-07-17 12:21:28.596666+00:00
# 15583            4 2025-07-16 09:24:15+00:00 2025-07-17 12:22:41.430000+00:00
# 15584            1 2025-07-16 09:24:37+00:00 2025-07-17 12:22:43.693333+00:00
# 15628            2 2025-07-23 13:53:27+00:00 2025-07-23 12:53:40.493333+00:00
# 15636            2 2025-07-23 13:53:27+00:00 2025-07-23 12:54:09.563333+00:00
# 15639            2 2025-07-23 13:53:27+00:00 2025-07-23 12:54:17.413333+00:00
# 15641            1 2025-07-23 13:53:28+00:00 2025-07-23 12:54:24.563333+00:00
# 15646            2 2025-07-23 13:53:26+00:00 2025-07-23 12:54:36.953333+00:00
# 15650            2 2025-07-23 13:53:27+00:00 2025-07-23 12:54:44.970000+00:00
#
#                             updated_at
# 48    2025-07-04 09:19:09.136666+00:00
# 107   2025-07-04 08:17:58.170000+00:00
# 108   2025-07-04 14:52:33.660000+00:00
# 109   2025-07-04 14:53:18.750000+00:00
# 111   2025-07-04 14:53:18.753333+00:00
# 113   2025-07-04 09:19:09.143333+00:00
# 114   2025-07-04 15:06:41.186666+00:00
# 146          2025-07-07 12:45:15+00:00
# 150   2025-07-04 14:53:29.920000+00:00
# 168   2025-07-04 14:53:07.570000+00:00
# 169   2025-07-04 14:53:07.573333+00:00
# 170   2025-07-04 14:53:07.576666+00:00
# 171   2025-07-04 14:53:07.580000+00:00
# 172   2025-07-04 14:52:41.306666+00:00
# 173   2025-07-04 14:53:07.583333+00:00
# 174   2025-07-04 14:52:41.313333+00:00
# 175   2025-07-04 14:53:07.586666+00:00
# 252   2025-07-04 09:13:57.723333+00:00
# 255   2025-07-04 09:13:57.726666+00:00
# 290   2025-07-04 14:53:13.693333+00:00
# 535   2025-07-17 15:35:29.270000+00:00
# 544   2025-07-17 12:22:21.760000+00:00
# 4127  2025-07-08 15:00:19.626666+00:00
# 4607  2025-07-04 14:53:13.696666+00:00
# 5474  2025-07-17 12:22:12.620000+00:00
# 6741  2025-07-04 14:53:13.696666+00:00
# 6750  2025-07-04 14:53:13.700000+00:00
# 7211  2025-07-04 14:52:37.836666+00:00
# 7212  2025-07-04 14:53:01.720000+00:00
# 7243  2025-07-04 15:17:24.073333+00:00
# 7244  2025-07-04 15:17:24.080000+00:00
# 13601 2025-07-08 15:00:19.630000+00:00
# 13608 2025-07-08 15:00:19.633333+00:00
# 13630 2025-07-08 15:00:19.640000+00:00
# 13632 2025-07-08 15:00:19.643333+00:00
# 13761 2025-07-08 15:00:19.646666+00:00
# 13775 2025-07-08 15:00:19.650000+00:00
# 14002 2025-07-08 15:00:19.653333+00:00
# 14011 2025-07-08 15:00:19.660000+00:00
# 15181 2025-07-17 12:24:13.003333+00:00
# 15560 2025-07-17 15:39:25.050000+00:00
# 15561 2025-07-17 15:39:25.053333+00:00
# 15583 2025-07-17 15:39:25.266666+00:00
# 15584 2025-07-17 15:39:25.063333+00:00
# 15628 2025-07-23 12:58:54.830000+00:00
# 15636 2025-07-23 12:58:54.836666+00:00
# 15639 2025-07-23 12:58:54.843333+00:00
# 15641 2025-07-23 12:58:54.846666+00:00
# 15646 2025-07-23 12:58:54.850000+00:00
# 15650 2025-07-23 12:58:54.850000+00:00
